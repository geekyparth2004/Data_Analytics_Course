# %%
import matplotlib.pyplot as plt 

y = [23,129,19,8]
x = ["Parth","Khushboo","Naman","Rahul"]

plt.bar(x,y)
plt.show()

# %%
plt.xlabel("Name",fontsize = 20)
plt.ylabel("Performance",fontsize = 20)
color = ["Yellow","Green","Yellow","Red"]
plt.bar(x,y,color = color)
plt.show()
