# %%
import matplotlib.pyplot as plt

y = [23,129,19,8]
x = ["Parth","Khushboo","Naman","Rahul"]

plt.plot(x,y,marker = "o")

# %%
plt.plot(x, y, ls=":", marker="o")

plt.legend()
plt.show()
# Out:
# /var/folders/rw/4z90slgd615fs0bzl_pn61400000gn/T/ipykernel_2193/1238040927.py:3: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
