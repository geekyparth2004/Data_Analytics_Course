# %%
import matplotlib.pyplot as plt 

brands = ["Apple","OnePlus","Oppo","Vivo"]
x = [78,5,7,10]
c= ["Silver","Red","Green","Yellow"]
ex = [0,0,0,.2]
plt.pie(x, labels = brands,colors= c,explode=ex,shadow=True,autopct="%.2f",startangle=90)
plt.show()
