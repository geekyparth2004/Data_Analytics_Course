# %%
import pandas as pd

data = pd.read_csv("/Users/parthgoel/Desktop/Data_Analytics_Course/Assets/registrations.csv")

print(data)
# Out:
#       Team ID                    Team Name Candidate Type  \
# 0    U967LFS4                          NaN         Leader
# 1    UTF877B5                CHANGE MAKERS         Leader
# 2    UTF877B5                CHANGE MAKERS         Member
# 3    UTF877B5                CHANGE MAKERS         Member
# 4    UE5738CD                  Synergy Six         Leader
# ..        ...                          ...            ...
# 966  U314XF5Z  harikarthigeyan.ev.mct.2022         Leader
# 967  U6M8JB74         mohammedroshan201104         Leader
# 968  UA800H7F              samruddhid.ai23         Leader
# 969  UA800H7F              samruddhid.ai23         Member
# 970  U0AK141E           abinash.a.bio.2022         Leader
#
#            Candidate's Name                      Candidate's Email  \
# 0             Sk Reaj Uddin                     skreaj92@gmail.com
# 1               Akash Verma               akashverma0401@gmail.com
# ...

# %%
data.loc[(data["Candidate Type"]=="Leader"),"Staus"] = "Important"
data.loc[(data["Candidate Type"]=="Member"),"Status"] = "Not Important"

print(data.head(10))
# Out:
#     Team ID      Team Name Candidate Type        Candidate's Name  \
# 0  U967LFS4            NaN         Leader           Sk Reaj Uddin
# 1  UTF877B5  CHANGE MAKERS         Leader             Akash Verma
# 2  UTF877B5  CHANGE MAKERS         Member            Anchal Priya
# 3  UTF877B5  CHANGE MAKERS         Member  Shashwat mani Tripathi
# 4  UE5738CD    Synergy Six         Leader        Harsh Khandelwal
# 5  UMO92K97   sahusuhani14         Leader             Suhani Sahu
# 6  UMO92K97   sahusuhani14         Member             VIDHI GUPTA
# 7  U1YQ621D     21eg105d62         Leader    Smruti Rekha Pradhan
# 8  U1YQ621D     21eg105d62         Member    Pranathi Proddhaturi
# 9  U1YQ621D     21eg105d62         Member          Tahura Afsheen
#
#                 Candidate's Email  Candidate's Mobile Candidate's Gender  \
# 0              skreaj92@gmail.com        918895946889                  M
# 1        akashverma0401@gmail.com        917428832025                  M
# ...

# %% [markdown]
# Alternate way to make a column

# %%
data["Mobile"] = data["Candidate's Mobile"]/100 

print(data)
# Out:
#       Team ID                    Team Name Candidate Type  \
# 0    U967LFS4                          NaN         Leader
# 1    UTF877B5                CHANGE MAKERS         Leader
# 2    UTF877B5                CHANGE MAKERS         Member
# 3    UTF877B5                CHANGE MAKERS         Member
# 4    UE5738CD                  Synergy Six         Leader
# ..        ...                          ...            ...
# 966  U314XF5Z  harikarthigeyan.ev.mct.2022         Leader
# 967  U6M8JB74         mohammedroshan201104         Leader
# 968  UA800H7F              samruddhid.ai23         Leader
# 969  UA800H7F              samruddhid.ai23         Member
# 970  U0AK141E           abinash.a.bio.2022         Leader
#
#            Candidate's Name                      Candidate's Email  \
# 0             Sk Reaj Uddin                     skreaj92@gmail.com
# 1               Akash Verma               akashverma0401@gmail.com
# ...
